# %%
import pandas as pd

# %%
data= pd.read_table("C:/Users/actionfi/Desktop/Extractors_Demo/FXRATE_AMS_BlankColumnDate_20190522131517.txt")
data
# Out:
#           date fromcurrency tocurrency  exchangerate typeid  customtext
# 0    4/30/2019          AED        AED       1.00000      M         NaN
# 1    4/30/2019          AED        EUR       0.01000      M         NaN
# 2    4/30/2019          AED        GBP     100.00000      M         NaN
# 3    4/30/2019          AED        JPY       0.31250      M         NaN
# 4          NaN          AED        QAR       0.98545      M         NaN
# 5    4/30/2019          AED        SGD       0.01299      M         NaN
# 6    4/30/2019          AED        USD       0.27174      M         NaN
# 7    4/30/2019          ARS        ARS       0.20000      M         NaN
# 8    4/30/2019          ARS        BRL       1.95100      M         NaN
# 9    4/30/2019          ARS        CAD       1.49600      M         NaN
# 10   4/30/2019          ARS        CLP     575.28000      M         NaN
# 11   4/30/2019          ARS        COP       2.21300      M         NaN
# ...

# %%
data1= data[["month","day","year"]] = data['date'].str.split("/",expand=True)
# data1
data
# Out:
#           date fromcurrency tocurrency  exchangerate typeid  customtext month  \
# 0    4/30/2019          AED        AED       1.00000      M         NaN     4
# 1    4/30/2019          AED        EUR       0.01000      M         NaN     4
# 2    4/30/2019          AED        GBP     100.00000      M         NaN     4
# 3    4/30/2019          AED        JPY       0.31250      M         NaN     4
# 4          NaN          AED        QAR       0.98545      M         NaN   NaN
# 5    4/30/2019          AED        SGD       0.01299      M         NaN     4
# 6    4/30/2019          AED        USD       0.27174      M         NaN     4
# 7    4/30/2019          ARS        ARS       0.20000      M         NaN     4
# 8    4/30/2019          ARS        BRL       1.95100      M         NaN     4
# 9    4/30/2019          ARS        CAD       1.49600      M         NaN     4
# 10   4/30/2019          ARS        CLP     575.28000      M         NaN     4
# ...
